# %%
# Final Year Project - Deepfake Detection Using Vision Transoformers

################################### IMPORTS ###################################
import torch # using PyTorch
import pandas as pd
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
import torchvision
from torchvision import transforms # for data augmentation
from torchvision.transforms import v2 # also for augmentation
from torch.utils.data import DataLoader, Dataset
from PIL import Image
from IPython.display import Image
from torchvision import datasets
import pandas as pd
from transformers import AutoImageProcessor
from torch import nn
from torch.nn import Module, ModuleList
import math
# for training
import time
from transformers import TrainingArguments
from transformers import Trainer as Trainer1 #helps avoid confusion between methods 1 and 2
import time #for measuring duration of training methods
from sklearn.metrics import accuracy_score #method 1
from google.colab import drive # for CUDA
drive.mount('/content/drive', force_remount=True)
import evaluate
# Out:
# Mounted at /content/drive

# %%
################################ CONFIGURATION #################################

config = {
    "image_size": 72,
    "patch_size": 6,
    "dim": 64,
    "nr_channels": 3,
    "nr_layers": 4,
    "nr_heads": 4,
    "nr_classes": 2, # real or fake
    "dropout": 0,
    "r_mlp": 4,
}

################################ TRAINING ARGS #################################

train_args = {
    "learning_rate": 0.001,
    "weight_decay": 0.0001,
    "batch_size":  256,
    "epochs" : 100,
    "num_workers": 2, #2 cores from colab free
    "pin_memory": True
}

# %%
################################## DATA PATHS ##################################
base_path = "/content/drive/My Drive/Colab Notebooks/FinalProject/Dataset"

#train, test, val data paths # # ~ 190.3k otal
train_path = base_path + "/Train" #~140k (70k real, 70k fake)
val_path = base_path + "/Validation" #~39.4k (~19700 real, -//- fake)
test_path = base_path + "/Test" #~10.9k (~5450 real, -//- fake)

############################## DATA AUGMENTATION ###############################

# https://docs.pytorch.org/vision/0.22/transforms.html
# recommended by pytorch for Image Classification
# additions from https://medium.com/@BurtMcGurt/a-practical-guide-to-data-augmentation-in-pytorch-with-examples-and-visualizations-761ad5c2a903
# https://github.com/Deadly-Finisher/-Deep-Fake-Image-Detection-using-PyTorch/blob/main/Deep_Fake.ipynb

train_transforms = v2.Compose([
    v2.ToImage(), # needed only if PIL image
    v2.Resize((config["image_size"], config["image_size"])),
    v2.RandomHorizontalFlip(p=0.5),
    v2.RandomRotation(degrees=10),
    v2.ColorJitter(brightness=0.3, contrast=0.3, saturation=0.3),
    v2.ToDtype(torch.float32, scale=True),
    v2.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

val_transforms = v2.Compose([
    v2.ToImage(),
    v2.Resize((config["image_size"], config["image_size"])),
    v2.ToDtype(torch.float32, scale=True),
    v2.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

test_transforms = v2.Compose([
    v2.ToImage(),
    v2.Resize((config["image_size"], config["image_size"])),
    v2.ToDtype(torch.float32, scale=True),
    v2.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])


################################# LOADING DATA #################################
# https://github.com/Deadly-Finisher/-Deep-Fake-Image-Detection-using-PyTorch/blob/main/Deep_Fake.ipynb

# Load data
train_data = datasets.ImageFolder(train_path, train_transforms)
val_data = datasets.ImageFolder(val_path, val_transforms)
test_data = datasets.ImageFolder(test_path, test_transforms)

dataloaders = {
    "train": DataLoader(train_data, batch_size=train_args["batch_size"], shuffle=True),
    "val": DataLoader(val_data, batch_size=train_args["batch_size"], shuffle=False),
    "test": DataLoader(test_data, batch_size=train_args["batch_size"], shuffle=False)
}

dataset_sizes = {
    "train": len(train_data),
    "val": len(val_data),
    "test": len(test_data)
}
class_names = train_data.classes

#pirnting info
print(f"Classes: {class_names}")
print(f"Train dataset size: {dataset_sizes["train"]}")
print(f"Validation dataset size: {dataset_sizes["val"]}")
print(f"Test dataset size: {dataset_sizes["test"]}")
# Out:
# Classes: ['Fake', 'Real']
# Train dataset size: 140002
# Validation dataset size: 39428
# Test dataset size: 10905

# %%
################################## ViT MODEL ###################################

# patch embedding
class PatchEmbeddings(Module):
    #converting images into patches

    def __init__(self, config):
        super().__init__()
        self.image_size = config["image_size"]
        self.patch_size = config["patch_size"]
        self.emb_dim = config["dim"]
        self.nr_channels = config["nr_channels"]

        self.nr_patches = (self.image_size // self.patch_size) ** 2

        self.project = nn.Conv2d(self.nr_channels, self.emb_dim, kernel_size=self.patch_size, stride=self.patch_size)


    def forward(self, x):
        #batch size, channels, img height, img width > b, emb_dim, patch col, patch row
        x = self.project(x)

        # b, emb_dim, patch col, patch row > b, emb_dim, nr_patches
        x = x.flatten(2)

        #b, dim, patch > b, nr_patches, emb_dim
        x = x.transpose(1,2)

        return x


#positional encoding and class token
class PositionalEmbeddings(Module):
    def __init__(self, config):
        super().__init__()
        self.patch_embeddings = PatchEmbeddings(config)
        nr_patches = (config["image_size"] // config["patch_size"]) ** 2

        # creating classification token
        self.cls_token = nn.Parameter(torch.randn(1, 1, config["dim"]))

        # position emb for the csl token and patches
        self.position_emb = nn.Parameter(torch.randn(1, nr_patches + 1, config["dim"]));

    def forward(self, x):
        # x = self.position_emb(x)
        B = x.size(0)
        x = self.patch_embeddings(x)
        # getting batch size, nr patches and dim
        # b, n, _ = x.shape

        # expanding tokens
        #cls_tokens = self.cls_token.expand(b, -1, -1)
        #tokens = self.cls_token.expand(x.size()[0], -1, -1) # only expanding batch dim, nothing else
        tokens = self.cls_token.expand(B, -1, -1)
        # concatenate token to start of patches
        x = torch.cat((tokens, x), dim = 1)

        # adding positional encoding to embeddins before being outputted
        x = x + self.position_emb
        return x

#single attention head
class Attention(Module):
    #global relationships between patches
    #dependency modelling and spatial context

    def __init__(self, config, head_size):
        super().__init__()
        self.head_size = head_size
        self.dim = config["dim"]
        # inner_dim = self.dim * self.nr_heads
        self.dropout = nn.Dropout(config["dropout"]) #dropout used to prevent overfitting

        self.key = nn.Linear(self.dim, self.head_size)
        self.val = nn.Linear(self.dim, self.head_size)
        self.query = nn.Linear(self.dim, self.head_size)

        #self.to_qkv = nn.Linear(self.dim, inner_dim * 3) # into kets, vals and queries

    def forward(self, x):
        #qkv = self.to_qkv(x).chunk(3, dim = -1)
        #batch_size, nr_patches, inner_dim TO nr_heads, nr_patches, dim_head
        #query, key, val = map(lambda t: rearrange(t), qkv)
        key = self.key(x)
        val = self.val(x)
        query = self.query(x)

        # score = how similar the patch is to other pathces
        # probs = scores but changed to weights
        # output = final result of each head, basically a weighted average of info

        attn_scores = (torch.matmul(query, key.transpose(-1,-2))) / math.sqrt(self.head_size)
        attn_probs = nn.functional.softmax(attn_scores, dim = -1)
        attn_probs = self.dropout(attn_probs)
        output = torch.matmul(attn_probs, val)
        return (output, attn_probs)

class MultiHeadAttention(Module):
    # parallel attention heads
    def __init__(self, config):
        super().__init__()
        self.dim = config["dim"]
        self.nr_heads = config["nr_heads"]
        self.head_size = self.dim // self.nr_heads
        self.heads = nn.ModuleList([Attention(config, self.head_size) for _ in range(self.nr_heads)])

        self.to_out = nn.Linear(self.dim, self.dim)

    def forward(self, x):
        out = torch.cat([head(x)[0] for head in self.heads], dim = -1) # 0 gives output, 1 gives probs
        output = self.to_out(out)
        return output


# Multilayer Perceptron / Feed forward Network
class MLP(Module):
    #intorduces non-linearity and for learning complex features
    def __init__(self, config):
        super().__init__()
        self.dim = config["dim"]
        self.dropout = config["dropout"]
        self.r_mlp = config["r_mlp"]
        hidden_dim = self.dim * self.r_mlp
        self.mlp = nn.Sequential(
            nn.Linear(self.dim, hidden_dim),
            nn.GELU(),
            nn.Dropout(self.dropout),
            nn.Linear(hidden_dim, self.dim),
            nn.Dropout(self.dropout)
        )


    def forward(self,x):
        output= self.mlp(x)
        return output


# transofmrer encoder blocks (self attention and Multilayer Perceptron (mlp))
class Encoder(Module):
    # transformer encoder module:
    #layer normalisation
    # multi-head attention
    # residual connections
    # multi layer perception

    def __init__(self, config):
        super().__init__()
        # self.nr_heads = config["nr_heads"]
        self.dim = config["dim"]
        # self.r_mlp = config["r_mlp"]
        # self.dropout = nn.Dropout(config["dropout"])
        #hidden_dim = self.dim * self.r_mlp

        #layer normalisation
        self.norm = nn.LayerNorm(self.dim)
        # multi-head attention
        self.mha = MultiHeadAttention(config)
        # multi layer perception
        self.mlp = MLP(config)
        #nn.Sequential(
        #    nn.Linear(self.dim, hidden_dim),
        #    nn.GELU(), # or ReLU ???
        #    nn.Linear(hidden_dim, self.dim)
        #)
        #self.layers = nn.ModuleList([])


    def forward(self, x):
        x = x + self.mha(self.norm(x)) # after sublayer 1
        output = x + self.mlp(self.norm(x)) #after sublayer 2
        return output

#classification head
class ViTForClassification(Module):

        # self.depth = 0; # how many transformer layers
        # self.batch_size = 0;
        # self.emb_dropout = 0; # dropout rate for embedding

    #def __init__(self, dim, nr_classes, img_size, patch_size, nr_channels, nr_heads, nr_layers):
    def __init__(self,config):
        super().__init__()

        #self.encoder = Encoder(config)
        #self.classifier = nn.Linear(hidden_size, nr_classes)

        # following config build
        self.dim = config["dim"]
        self.image_size = config["image_size"]
        self.patch_size = config["patch_size"]
        self.nr_heads = config["nr_heads"]
        self.nr_channels = config["nr_channels"]
        self.nr_classes = config["nr_classes"]
        self.dropout = config["dropout"]
        self.loss_fn = nn.CrossEntropyLoss()

        #going through each class
        self.positional_emb = PositionalEmbeddings(config)
        #self.cls_token = nn.Parameter(torch.randn(1,1, self.dim))
        #self.encoders = Encoder(config)
        self.encoders = nn.ModuleList([Encoder(config) for _ in range(config["nr_layers"])])
        self.norm = nn.LayerNorm(self.dim)
        # linear layer to project encoders output to nr of classes
        self.classifier = nn.Linear(self.dim, self.nr_classes)

#https://huggingface.co/docs/transformers/v4.27.0/en/main_classes/trainer
    def forward(self, img, labels=None):
        #now running data through each class
        x = self.positional_emb(img) #positional and patch emb
        for layer in self.encoders:
            x = layer(x)

        x = self.norm(x)
        output = self.classifier(x[:, 0])

        #A7
        loss = None
        if labels is not None: #for training method 1
            loss = self.loss_fn(output, labels)
            return (loss, output)

        return output

# %%
################################### EPOCH RUN ##################################

# https://stackoverflow.com/questions/59005242/how-to-get-n-number-of-images-from-torchvision-datasets-imagefolder
# https://docs.pytorch.org/tutorials/beginner/blitz/cifar10_tutorial.html


#dataset = torchvision.datasets.ImageFolder(...)
np.random.seed(42) # for fair comparisons
train_subset = torch.utils.data.Subset(train_data, np.random.choice(len(train_data), 10000, replace=False))
val_subset = torch.utils.data.Subset(val_data, np.random.choice(len(val_data), 2500, replace=False))

subsetloaders = {
    "train": DataLoader(train_subset, batch_size=train_args["batch_size"], shuffle=True),
    "val": DataLoader(val_subset, batch_size=train_args["batch_size"], shuffle=False)
}

def imshow(img):
    # mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]
    img = img / 2 + 0.5     # unnormalize, tho not fully so colours will be slightly off (but this is insignificant for a small scale run)
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()


# get some random training images
dataiter = iter(subsetloaders["train"])
images, labels = next(dataiter)

# show images
imshow(torchvision.utils.make_grid(images[:16])) # showing only 10 images for display
# print labels
#print('Labels: '.join(f'{classes[labels[j]]:5s}' for j in range(4)))
print('Labels: ', ' | '.join(f'{class_names[labels[j]]}' for j in range(16)))
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.558952..1.82].
# Labels:  Fake | Fake | Fake | Real | Fake | Fake | Fake | Fake | Real | Fake | Fake | Real | Fake | Fake | Fake | Fake

# %%
################################### TRAINING ##################################
# METHOD THREE

torch.manual_seed(42)

device = "cuda"if torch.cuda.is_available() else "cpu"
print(device)

loss_fn = nn.CrossEntropyLoss()

model = ViTForClassification(config).to(device)

optimizer = torch.optim.AdamW(model.parameters(),
                              lr = train_args["learning_rate"],
                              weight_decay = train_args["weight_decay"])


criterion = nn.CrossEntropyLoss().to(device)

################################## CHECKPOINTS #################################
checkpoint_path = "/content/drive/My Drive/Colab Notebooks/FinalProject/Checkpoints/checkpoint.pt"


train_losses = []
val_losses = []

#method three
# https://github.com/pytorch/examples/blob/main/imagenet/main.py
class AverageMeter(object):
    def __init__(self, name):
        self.name = name
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count


def accuracy(output, target):
    with torch.no_grad():
        batch_size = target.size(0)
        _, pred = output.topk(1, 1, True, True)
        pred = pred.t()

        correct = pred.eq(target.view(1, -1).expand_as(pred))
        correct_1 = correct[:1].reshape(-1).float().sum(0, keepdim=True)
        res= correct_1.mul_(100.0 / batch_size)
        return res


def train(train_loader, model, criterion, optimizer, device):
    losses = AverageMeter("Loss")

    # switch to train mode
    model.train()

    start = time.time()
    for i, (images, target) in enumerate(train_loader):

        # move data to the same device as model
        images = images.to(device, non_blocking=True)
        target = target.to(device, non_blocking=True)

        # compute output
        output = model(images)
        loss = criterion(output, target)

        #record loss
        losses.update(loss.item(), images.size(0))

        # compute gradient and do SGD step
        optimizer.zero_grad() #clearing old gradients
        loss.backward() #new gradients
        optimizer.step() #updating weights

    return losses.avg


def validate(valloader, model, criterion, device):
    model.eval()
    losses = AverageMeter("Loss")
    acc = AverageMeter("Accuracy")

    model.eval()

    with torch.no_grad():
        for i, (images, target) in enumerate(valloader):
            images = images.to(device)
            target = target.to(device)

            output = model(images)
            loss = criterion(output, target)

            #calculating accuracy for method comparison
            acc1 = accuracy(output, target).item()

            losses.update(loss.item(), images.size(0))
            acc.update(acc1, images.size(0))

    return losses.avg, acc.avg



#avg loss from https://github.com/aidendorian/Vision-Transformer-for-DeepFake-Detection/blob/master/pre_training.py
start_time = time.time()
best_acc = 0
start_epoch = 0 # for checkpointing

# for loading from checkpoint if timed out
#checkpoint = torch.load(checkpoint_path)
#model.load_state_dict(checkpoint['model_state_dict'])
#optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
#start_epoch = checkpoint["epoch"] + 1
#best_acc = checkpoint["best_acc"]
#train_losses = checkpoint["train_losses"]
#val_losses = checkpoint["val_losses"]

for epoch in range(start_epoch, train_args["epochs"]):
    e_start_time = time.time()
    # for small run
    train_loss = train(subsetloaders["train"], model, criterion, optimizer,device)
    val_loss, acc = validate(subsetloaders["val"],model, criterion, device)
    e_end_time = time.time()
    #main runs
    #train_loss = train(dataloaders["train"], model, criterion, optimizer,device)
    #val_loss, acc = validate(dataloaders["val"],model, criterion, device)

    #for loss curves
    train_losses.append(train_loss)
    val_losses.append(val_loss)

    best_acc = max(acc, best_acc)

    #https://colab.research.google.com/github/pytorch/tutorials/blob/gh-pages/_downloads/dbcf5e6a5e95bf9f7a0e49e123c13b60/saving_and_loading_a_general_checkpoint.ipynb#scrollTo=GZZi4Al2lt4H
    #creating checkpoint at each epoch incase of Colab "timeout"
    torch.save({
                "epoch": epoch,
                "model_state_dict": model.state_dict(),
                "optimizer_state_dict": optimizer.state_dict(),
                "best_acc": best_acc,
                "train_losses": train_losses,
                "val_losses": val_losses,
                "config": config,
                "train_args": train_args
                }, checkpoint_path )

    print(f"METHOD 3: Epoch: {epoch+1}, Time: {e_end_time - e_start_time:.2f}s, Train loss: {train_loss:.4f}, Validation loss: {val_loss:.4f},  Accuracy: {acc:.2f}%,  Highest Accuracy: {best_acc:.2f}%")

end_time = time.time()
print(f"Duration of training: {end_time - start_time:.2f}s")
# Out:
# cuda
# METHOD 3: Epoch: 1, Time: 2577.18s, Train loss: 0.7090, Validation loss: 0.7028,  Accuracy: 51.32%,  Highest Accuracy: 51.32%
# METHOD 3: Epoch: 2, Time: 64.68s, Train loss: 0.6705, Validation loss: 0.6222,  Accuracy: 66.16%,  Highest Accuracy: 66.16%
# METHOD 3: Epoch: 3, Time: 64.77s, Train loss: 0.5894, Validation loss: 0.6166,  Accuracy: 68.04%,  Highest Accuracy: 68.04%
# METHOD 3: Epoch: 4, Time: 65.64s, Train loss: 0.5416, Validation loss: 0.6104,  Accuracy: 70.52%,  Highest Accuracy: 70.52%
# METHOD 3: Epoch: 5, Time: 65.24s, Train loss: 0.5292, Validation loss: 0.5605,  Accuracy: 71.20%,  Highest Accuracy: 71.20%
# METHOD 3: Epoch: 6, Time: 64.83s, Train loss: 0.5066, Validation loss: 0.5307,  Accuracy: 72.12%,  Highest Accuracy: 72.12%
# METHOD 3: Epoch: 7, Time: 64.80s, Train loss: 0.4873, Validation loss: 0.5327,  Accuracy: 71.72%,  Highest Accuracy: 72.12%
# METHOD 3: Epoch: 8, Time: 64.06s, Train loss: 0.4780, Validation loss: 0.5120,  Accuracy: 73.00%,  Highest Accuracy: 73.00%
# METHOD 3: Epoch: 9, Time: 64.72s, Train loss: 0.4691, Validation loss: 0.5155,  Accuracy: 73.32%,  Highest Accuracy: 73.32%
# METHOD 3: Epoch: 10, Time: 65.38s, Train loss: 0.4563, Validation loss: 0.5165,  Accuracy: 73.68%,  Highest Accuracy: 73.68%
# METHOD 3: Epoch: 11, Time: 64.20s, Train loss: 0.4508, Validation loss: 0.5052,  Accuracy: 75.08%,  Highest Accuracy: 75.08%
# METHOD 3: Epoch: 12, Time: 64.79s, Train loss: 0.4492, Validation loss: 0.5057,  Accuracy: 74.16%,  Highest Accuracy: 75.08%
# METHOD 3: Epoch: 13, Time: 64.10s, Train loss: 0.4319, Validation loss: 0.5705,  Accuracy: 71.04%,  Highest Accuracy: 75.08%
# METHOD 3: Epoch: 14, Time: 64.77s, Train loss: 0.4457, Validation loss: 0.4991,  Accuracy: 75.04%,  Highest Accuracy: 75.08%
# METHOD 3: Epoch: 15, Time: 64.59s, Train loss: 0.4316, Validation loss: 0.4919,  Accuracy: 75.72%,  Highest Accuracy: 75.72%
# METHOD 3: Epoch: 16, Time: 63.80s, Train loss: 0.4185, Validation loss: 0.4758,  Accuracy: 75.88%,  Highest Accuracy: 75.88%
# METHOD 3: Epoch: 17, Time: 64.49s, Train loss: 0.4178, Validation loss: 0.4930,  Accuracy: 75.48%,  Highest Accuracy: 75.88%
# METHOD 3: Epoch: 18, Time: 63.71s, Train loss: 0.4199, Validation loss: 0.5277,  Accuracy: 73.84%,  Highest Accuracy: 75.88%
# METHOD 3: Epoch: 19, Time: 64.38s, Train loss: 0.4138, Validation loss: 0.4755,  Accuracy: 77.28%,  Highest Accuracy: 77.28%
# METHOD 3: Epoch: 20, Time: 63.89s, Train loss: 0.3983, Validation loss: 0.4823,  Accuracy: 77.76%,  Highest Accuracy: 77.76%
# METHOD 3: Epoch: 21, Time: 63.28s, Train loss: 0.3958, Validation loss: 0.4668,  Accuracy: 77.12%,  Highest Accuracy: 77.76%
# METHOD 3: Epoch: 22, Time: 64.05s, Train loss: 0.3880, Validation loss: 0.4760,  Accuracy: 77.64%,  Highest Accuracy: 77.76%
# METHOD 3: Epoch: 23, Time: 62.89s, Train loss: 0.3865, Validation loss: 0.4781,  Accuracy: 76.96%,  Highest Accuracy: 77.76%
# METHOD 3: Epoch: 24, Time: 64.84s, Train loss: 0.3885, Validation loss: 0.4696,  Accuracy: 77.32%,  Highest Accuracy: 77.76%
# METHOD 3: Epoch: 25, Time: 64.67s, Train loss: 0.3775, Validation loss: 0.4547,  Accuracy: 77.96%,  Highest Accuracy: 77.96%
# METHOD 3: Epoch: 26, Time: 63.03s, Train loss: 0.3846, Validation loss: 0.5212,  Accuracy: 74.60%,  Highest Accuracy: 77.96%
# METHOD 3: Epoch: 27, Time: 63.83s, Train loss: 0.4051, Validation loss: 0.4583,  Accuracy: 77.96%,  Highest Accuracy: 77.96%
# METHOD 3: Epoch: 28, Time: 63.15s, Train loss: 0.3847, Validation loss: 0.4717,  Accuracy: 77.04%,  Highest Accuracy: 77.96%
# METHOD 3: Epoch: 29, Time: 64.82s, Train loss: 0.3660, Validation loss: 0.4892,  Accuracy: 77.08%,  Highest Accuracy: 77.96%
# METHOD 3: Epoch: 30, Time: 63.35s, Train loss: 0.3657, Validation loss: 0.4420,  Accuracy: 78.56%,  Highest Accuracy: 78.56%
# METHOD 3: Epoch: 31, Time: 64.86s, Train loss: 0.3620, Validation loss: 0.4526,  Accuracy: 77.68%,  Highest Accuracy: 78.56%
# METHOD 3: Epoch: 32, Time: 65.06s, Train loss: 0.3624, Validation loss: 0.4540,  Accuracy: 78.20%,  Highest Accuracy: 78.56%
# METHOD 3: Epoch: 33, Time: 64.86s, Train loss: 0.3552, Validation loss: 0.4764,  Accuracy: 77.04%,  Highest Accuracy: 78.56%
# METHOD 3: Epoch: 34, Time: 65.59s, Train loss: 0.3476, Validation loss: 0.4460,  Accuracy: 78.96%,  Highest Accuracy: 78.96%
# METHOD 3: Epoch: 35, Time: 65.31s, Train loss: 0.3593, Validation loss: 0.4366,  Accuracy: 78.80%,  Highest Accuracy: 78.96%
# METHOD 3: Epoch: 36, Time: 68.12s, Train loss: 0.3423, Validation loss: 0.4440,  Accuracy: 78.16%,  Highest Accuracy: 78.96%
# METHOD 3: Epoch: 37, Time: 65.85s, Train loss: 0.3390, Validation loss: 0.4551,  Accuracy: 79.00%,  Highest Accuracy: 79.00%
# METHOD 3: Epoch: 38, Time: 65.41s, Train loss: 0.3305, Validation loss: 0.4427,  Accuracy: 79.80%,  Highest Accuracy: 79.80%
# METHOD 3: Epoch: 39, Time: 65.92s, Train loss: 0.3263, Validation loss: 0.4829,  Accuracy: 77.72%,  Highest Accuracy: 79.80%
# METHOD 3: Epoch: 40, Time: 66.26s, Train loss: 0.3449, Validation loss: 0.4458,  Accuracy: 78.88%,  Highest Accuracy: 79.80%
# METHOD 3: Epoch: 41, Time: 66.09s, Train loss: 0.3253, Validation loss: 0.4462,  Accuracy: 78.56%,  Highest Accuracy: 79.80%
# METHOD 3: Epoch: 42, Time: 65.28s, Train loss: 0.3214, Validation loss: 0.4365,  Accuracy: 79.24%,  Highest Accuracy: 79.80%
# METHOD 3: Epoch: 43, Time: 65.11s, Train loss: 0.3216, Validation loss: 0.4530,  Accuracy: 78.56%,  Highest Accuracy: 79.80%
# METHOD 3: Epoch: 44, Time: 65.18s, Train loss: 0.3235, Validation loss: 0.4578,  Accuracy: 77.08%,  Highest Accuracy: 79.80%
# METHOD 3: Epoch: 45, Time: 65.08s, Train loss: 0.3107, Validation loss: 0.4543,  Accuracy: 79.16%,  Highest Accuracy: 79.80%
# METHOD 3: Epoch: 46, Time: 65.66s, Train loss: 0.3118, Validation loss: 0.4435,  Accuracy: 79.44%,  Highest Accuracy: 79.80%
# METHOD 3: Epoch: 47, Time: 65.93s, Train loss: 0.3095, Validation loss: 0.4522,  Accuracy: 79.04%,  Highest Accuracy: 79.80%
# METHOD 3: Epoch: 48, Time: 65.87s, Train loss: 0.3059, Validation loss: 0.4670,  Accuracy: 78.52%,  Highest Accuracy: 79.80%
# METHOD 3: Epoch: 49, Time: 64.90s, Train loss: 0.2990, Validation loss: 0.4545,  Accuracy: 79.72%,  Highest Accuracy: 79.80%
# METHOD 3: Epoch: 50, Time: 65.82s, Train loss: 0.2889, Validation loss: 0.4389,  Accuracy: 79.88%,  Highest Accuracy: 79.88%
# METHOD 3: Epoch: 51, Time: 65.01s, Train loss: 0.2789, Validation loss: 0.4415,  Accuracy: 79.76%,  Highest Accuracy: 79.88%
# METHOD 3: Epoch: 52, Time: 64.90s, Train loss: 0.2879, Validation loss: 0.4680,  Accuracy: 79.40%,  Highest Accuracy: 79.88%
# METHOD 3: Epoch: 53, Time: 65.48s, Train loss: 0.2940, Validation loss: 0.4502,  Accuracy: 79.36%,  Highest Accuracy: 79.88%
# METHOD 3: Epoch: 54, Time: 64.60s, Train loss: 0.2847, Validation loss: 0.4883,  Accuracy: 78.28%,  Highest Accuracy: 79.88%
# METHOD 3: Epoch: 55, Time: 65.63s, Train loss: 0.2892, Validation loss: 0.4433,  Accuracy: 79.48%,  Highest Accuracy: 79.88%
# METHOD 3: Epoch: 56, Time: 65.73s, Train loss: 0.2675, Validation loss: 0.4545,  Accuracy: 79.32%,  Highest Accuracy: 79.88%
# METHOD 3: Epoch: 57, Time: 65.07s, Train loss: 0.2926, Validation loss: 0.4524,  Accuracy: 79.96%,  Highest Accuracy: 79.96%
# METHOD 3: Epoch: 58, Time: 65.57s, Train loss: 0.2826, Validation loss: 0.4583,  Accuracy: 78.76%,  Highest Accuracy: 79.96%
# METHOD 3: Epoch: 59, Time: 65.69s, Train loss: 0.2626, Validation loss: 0.4485,  Accuracy: 80.24%,  Highest Accuracy: 80.24%
# METHOD 3: Epoch: 60, Time: 64.31s, Train loss: 0.2631, Validation loss: 0.4999,  Accuracy: 78.20%,  Highest Accuracy: 80.24%
# METHOD 3: Epoch: 61, Time: 65.86s, Train loss: 0.2715, Validation loss: 0.4659,  Accuracy: 79.56%,  Highest Accuracy: 80.24%
# METHOD 3: Epoch: 62, Time: 64.98s, Train loss: 0.2744, Validation loss: 0.4809,  Accuracy: 78.20%,  Highest Accuracy: 80.24%
# METHOD 3: Epoch: 63, Time: 64.81s, Train loss: 0.2874, Validation loss: 0.4613,  Accuracy: 79.28%,  Highest Accuracy: 80.24%
# METHOD 3: Epoch: 64, Time: 65.57s, Train loss: 0.2644, Validation loss: 0.4646,  Accuracy: 79.92%,  Highest Accuracy: 80.24%
# METHOD 3: Epoch: 65, Time: 65.17s, Train loss: 0.2541, Validation loss: 0.4400,  Accuracy: 80.80%,  Highest Accuracy: 80.80%
# METHOD 3: Epoch: 66, Time: 64.79s, Train loss: 0.2571, Validation loss: 0.4453,  Accuracy: 79.04%,  Highest Accuracy: 80.80%
# METHOD 3: Epoch: 67, Time: 65.42s, Train loss: 0.3025, Validation loss: 0.4596,  Accuracy: 79.68%,  Highest Accuracy: 80.80%
# METHOD 3: Epoch: 68, Time: 64.62s, Train loss: 0.2617, Validation loss: 0.4535,  Accuracy: 79.48%,  Highest Accuracy: 80.80%
# METHOD 3: Epoch: 69, Time: 65.83s, Train loss: 0.2547, Validation loss: 0.4430,  Accuracy: 79.72%,  Highest Accuracy: 80.80%
# METHOD 3: Epoch: 70, Time: 65.38s, Train loss: 0.2603, Validation loss: 0.4909,  Accuracy: 79.16%,  Highest Accuracy: 80.80%
# METHOD 3: Epoch: 71, Time: 64.25s, Train loss: 0.2712, Validation loss: 0.4913,  Accuracy: 79.80%,  Highest Accuracy: 80.80%
# METHOD 3: Epoch: 72, Time: 66.17s, Train loss: 0.2523, Validation loss: 0.4439,  Accuracy: 81.04%,  Highest Accuracy: 81.04%
# METHOD 3: Epoch: 73, Time: 65.03s, Train loss: 0.2409, Validation loss: 0.4485,  Accuracy: 80.56%,  Highest Accuracy: 81.04%
# METHOD 3: Epoch: 74, Time: 64.49s, Train loss: 0.2597, Validation loss: 0.4671,  Accuracy: 79.44%,  Highest Accuracy: 81.04%
# METHOD 3: Epoch: 75, Time: 65.08s, Train loss: 0.2398, Validation loss: 0.4415,  Accuracy: 80.16%,  Highest Accuracy: 81.04%
# METHOD 3: Epoch: 76, Time: 65.88s, Train loss: 0.2429, Validation loss: 0.4349,  Accuracy: 80.52%,  Highest Accuracy: 81.04%
# METHOD 3: Epoch: 77, Time: 64.74s, Train loss: 0.2362, Validation loss: 0.4735,  Accuracy: 80.28%,  Highest Accuracy: 81.04%
# METHOD 3: Epoch: 78, Time: 65.58s, Train loss: 0.2209, Validation loss: 0.4479,  Accuracy: 81.04%,  Highest Accuracy: 81.04%
# METHOD 3: Epoch: 79, Time: 64.64s, Train loss: 0.2409, Validation loss: 0.4776,  Accuracy: 80.12%,  Highest Accuracy: 81.04%
# METHOD 3: Epoch: 80, Time: 64.16s, Train loss: 0.2220, Validation loss: 0.4563,  Accuracy: 79.96%,  Highest Accuracy: 81.04%
# METHOD 3: Epoch: 81, Time: 65.51s, Train loss: 0.2307, Validation loss: 0.4708,  Accuracy: 80.28%,  Highest Accuracy: 81.04%
# METHOD 3: Epoch: 82, Time: 65.03s, Train loss: 0.2177, Validation loss: 0.4693,  Accuracy: 80.16%,  Highest Accuracy: 81.04%
# METHOD 3: Epoch: 83, Time: 65.22s, Train loss: 0.2222, Validation loss: 0.4553,  Accuracy: 81.12%,  Highest Accuracy: 81.12%
# METHOD 3: Epoch: 84, Time: 65.33s, Train loss: 0.2031, Validation loss: 0.4855,  Accuracy: 80.24%,  Highest Accuracy: 81.12%
# METHOD 3: Epoch: 85, Time: 64.49s, Train loss: 0.2138, Validation loss: 0.4858,  Accuracy: 79.76%,  Highest Accuracy: 81.12%
# METHOD 3: Epoch: 86, Time: 66.37s, Train loss: 0.2225, Validation loss: 0.5064,  Accuracy: 80.00%,  Highest Accuracy: 81.12%
# METHOD 3: Epoch: 87, Time: 65.51s, Train loss: 0.2121, Validation loss: 0.4701,  Accuracy: 80.40%,  Highest Accuracy: 81.12%
# METHOD 3: Epoch: 88, Time: 64.01s, Train loss: 0.2025, Validation loss: 0.4644,  Accuracy: 80.92%,  Highest Accuracy: 81.12%
# METHOD 3: Epoch: 89, Time: 65.35s, Train loss: 0.1900, Validation loss: 0.4766,  Accuracy: 80.80%,  Highest Accuracy: 81.12%
# METHOD 3: Epoch: 90, Time: 65.64s, Train loss: 0.1998, Validation loss: 0.5497,  Accuracy: 79.32%,  Highest Accuracy: 81.12%
# METHOD 3: Epoch: 91, Time: 64.97s, Train loss: 0.2326, Validation loss: 0.4610,  Accuracy: 81.52%,  Highest Accuracy: 81.52%
# METHOD 3: Epoch: 92, Time: 65.40s, Train loss: 0.1952, Validation loss: 0.4702,  Accuracy: 79.84%,  Highest Accuracy: 81.52%
# METHOD 3: Epoch: 93, Time: 64.07s, Train loss: 0.1892, Validation loss: 0.4933,  Accuracy: 79.96%,  Highest Accuracy: 81.52%
# METHOD 3: Epoch: 94, Time: 63.37s, Train loss: 0.1814, Validation loss: 0.5436,  Accuracy: 80.12%,  Highest Accuracy: 81.52%
# METHOD 3: Epoch: 95, Time: 63.81s, Train loss: 0.1828, Validation loss: 0.5078,  Accuracy: 79.64%,  Highest Accuracy: 81.52%
# METHOD 3: Epoch: 96, Time: 64.51s, Train loss: 0.1903, Validation loss: 0.4965,  Accuracy: 80.40%,  Highest Accuracy: 81.52%
# METHOD 3: Epoch: 97, Time: 64.39s, Train loss: 0.1899, Validation loss: 0.4948,  Accuracy: 80.28%,  Highest Accuracy: 81.52%
# METHOD 3: Epoch: 98, Time: 63.53s, Train loss: 0.1767, Validation loss: 0.5234,  Accuracy: 79.88%,  Highest Accuracy: 81.52%
# METHOD 3: Epoch: 99, Time: 63.44s, Train loss: 0.1702, Validation loss: 0.5415,  Accuracy: 79.92%,  Highest Accuracy: 81.52%
# METHOD 3: Epoch: 100, Time: 63.92s, Train loss: 0.2155, Validation loss: 0.4738,  Accuracy: 80.76%,  Highest Accuracy: 81.52%
# Duration of training: 9011.62s

# %%
################################### LOSS CURVES ##################################

# it timed out after getting results.
checkpoint_path = "/content/drive/My Drive/Colab Notebooks/FinalProject/Checkpoints/checkpoint.pt"

checkpoint = torch.load(checkpoint_path, map_location=torch.device('cpu'))
train_losses = checkpoint["train_losses"]
val_losses = checkpoint["val_losses"]

#https://www.geeksforgeeks.org/deep-learning/training-and-validation-loss-in-deep-learning/
# plotting loss graphs
plt.figure(figsize=(8,5))
plt.title("Training vs Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.plot(train_losses, label="Training Loss")
plt.plot(val_losses, label="Validation Loss")
plt.legend()
plt.show()

# %%
# !pip install evaluate
# Out:
# Collecting evaluate
#   Downloading evaluate-0.4.6-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: datasets>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from evaluate) (4.0.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from evaluate) (2.0.2)
# Requirement already satisfied: dill in /usr/local/lib/python3.12/dist-packages (from evaluate) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from evaluate) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.12/dist-packages (from evaluate) (2.32.4)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.12/dist-packages (from evaluate) (4.67.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from evaluate) (3.6.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.12/dist-packages (from evaluate) (0.70.16)
# Requirement already satisfied: fsspec>=2021.05.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2021.05.0->evaluate) (2025.3.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from evaluate) (1.8.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from evaluate) (26.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets>=2.0.0->evaluate) (3.25.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.0.0->evaluate) (18.1.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.0.0->evaluate) (6.0.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2021.05.0->evaluate) (3.13.4)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.7.0->evaluate) (1.4.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.7.0->evaluate) (0.28.1)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.7.0->evaluate) (0.24.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.7.0->evaluate) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->evaluate) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->evaluate) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->evaluate) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->evaluate) (2026.2.25)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->evaluate) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->evaluate) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->evaluate) (2025.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.23.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.7.0->evaluate) (4.13.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.7.0->evaluate) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.7.0->evaluate) (0.16.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.17.0)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub>=0.7.0->evaluate) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub>=0.7.0->evaluate) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub>=0.7.0->evaluate) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub>=0.7.0->evaluate) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub>=0.7.0->evaluate) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub>=0.7.0->evaluate) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub>=0.7.0->evaluate) (0.1.2)
# Downloading evaluate-0.4.6-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 5.0 MB/s eta 0:00:00
# Installing collected packages: evaluate
# Successfully installed evaluate-0.4.6
